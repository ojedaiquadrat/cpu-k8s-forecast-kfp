# %% [markdown]
# import os
# import json
# import joblib
# import requests
# from minio import Minio
# from kafka import KafkaConsumer
# import numpy as np
# import pandas as pd
# from io import BytesIO
#
# # Kafka settings
# KAFKA_BOOTSTRAP_SERVERS = os.getenv("KAFKA_BOOTSTRAP_SERVERS", "kafka.apache-kafka.svc.cluster.local:9092")
# KAFKA_TOPIC = os.getenv("KAFKA_TOPIC", "sliding_window_lstm")
# KAFKA_GROUP_ID = os.getenv("KAFKA_GROUP_ID", "lstm-cpu-infer")
# INFERENCE_URL = os.getenv(
#     "INFERENCE_URL",
#     "http://inference-serving-kserve-cpu-pct.lstm-iqu.svc.cluster.local/v2/models/inference-serving-kserve-cpu-pct/infer"
# )
#
# # MinIO settings: match your deployment
# MINIO_ENDPOINT = os.getenv("MINIO_ENDPOINT", "minio-service.kubeflow.svc.cluster.local:9000")
# MINIO_ACCESS_KEY = os.getenv("MINIO_ACCESS_KEY", "minio")
# MINIO_SECRET_KEY = os.getenv("MINIO_SECRET_KEY", "minio123")
# MINIO_SECURE = os.getenv("MINIO_SECURE", "False").lower() == "true"
# MINIO_BUCKET = os.getenv("MINIO_BUCKET", "k8s-resources-forecast")
# MINIO_SCALER_OBJECT = os.getenv(
#     "MINIO_SCALER_OBJECT",
#     "data/k8s-preprocessed/node-1-cpu-scaler/node-1-scaler.pkl"
# )
# SCALER_FEATURE_NAME = os.getenv("SCALER_FEATURE_NAME", "ac3-node-1-vm_cpu_pct")  # Set to your actual column
#
# def fetch_scaler_from_minio():
#     """
#     Download the scaler from MinIO and load it using joblib.
#     """
#     client = Minio(
#         MINIO_ENDPOINT,
#         access_key=MINIO_ACCESS_KEY,
#         secret_key=MINIO_SECRET_KEY,
#         secure=MINIO_SECURE,
#     )
#     print(f"Downloading scaler from bucket '{MINIO_BUCKET}' object '{MINIO_SCALER_OBJECT}' ...")
#     data = client.get_object(MINIO_BUCKET, MINIO_SCALER_OBJECT)
#     scaler = joblib.load(BytesIO(data.read()))
#     data.close()
#     print("Scaler loaded from MinIO.")
#     return scaler
#
# def scale_window(window, scaler, feature_name):
#     """
#     Convert list of dicts to DataFrame with column, then scale.
#     """
#     cpu_vals = np.array([d["cpu_pct"] for d in window]).reshape(-1, 1)
#     cpu_df = pd.DataFrame(cpu_vals, columns=[feature_name])
#     scaled_vals = scaler.transform(cpu_df)
#     return scaled_vals.flatten().tolist()
#
# def send_inference(window_scaled):
#     """
#     Send the scaled window to the inference server and return the prediction.
#     """
#     payload = {
#         "inputs": [{
#             "name": "input-0",
#             "shape": [1, len(window_scaled), 1],
#             "datatype": "FP32",
#             "data": [[ [float(x)] for x in window_scaled ]]
#         }]
#     }
#     try:
#         resp = requests.post(INFERENCE_URL, json=payload, timeout=10)
#         if resp.status_code == 200:
#             try:
#                 result = resp.json()
#                 # Adjust as needed for your model output structure!
#                 pred = result["outputs"][0]["data"][0]
#                 return pred
#             except Exception as e:
#                 print(f"[ERROR] Failed to parse inference response: {e}")
#                 print("Body:", resp.text)
#                 return None
#         else:
#             print(f"[ERROR] Inference server HTTP {resp.status_code}: {resp.text}")
#             return None
#     except Exception as ex:
#         print(f"[ERROR] Exception in requests: {ex}")
#         return None
#
# def main():
#     scaler = fetch_scaler_from_minio()
#
#     consumer = KafkaConsumer(
#         KAFKA_TOPIC,
#         bootstrap_servers=[s.strip() for s in KAFKA_BOOTSTRAP_SERVERS.split(",") if s.strip()],
#         group_id=None,
#         value_deserializer=lambda v: json.loads(v.decode("utf-8")),
#         auto_offset_reset="latest",
#         enable_auto_commit=False
#     )
#
#     print(f"Subscribed to topic '{KAFKA_TOPIC}'. Waiting for windows...")
#     for msg in consumer:
#         window = msg.value
#         print("\nReceived window:", " | ".join(f"{d['ts'].split()[-1]} {d['cpu_pct']:.2f}" for d in window))
#         try:
#             window_scaled = scale_window(window, scaler, SCALER_FEATURE_NAME)
#             print("\nScaled window:", " | ".join(f"{x:.4f}" for x in window_scaled))
#             pred = send_inference(window_scaled)
#             print("\nForecasted value (scaled):", pred)
#             if pred is not None:
#                 # Inverse transform to original CPU % (always use a DataFrame to avoid warnings)
#                 pred_rescaled = scaler.inverse_transform(
#                     pd.DataFrame([[pred]], columns=[SCALER_FEATURE_NAME])
#                 )[0, 0]
#                 print("\nForecasted value (rescaled):", pred_rescaled)
#                 print("-----------------------------------------------------------------------------------------------\n")
#                 print("\n")
#         except Exception as e:
#             print("[ERROR] During processing window:", e)
#
# if __name__ == "__main__":
#     main()

# %% [markdown]
# # V2 extend the metrics and kafka publishing fro them
# n-memory buffer to store predictions until ground truth arrives
#
# Second Kafka producer for metrics
#
# Publishing to two topics:
#
# lstm_forecast_values (for forecasted + real value)
#
# lstm_forecast_metrics (for error + inference latency)
#
# Full debug printing
#
# You just need to provide the ground truth value when it arrives, for now this example simulates the ground truth as the last element of the window (as a placeholder). You can replace this logic as needed.

# %%
import os
import json
import joblib
import requests
from minio import Minio
from kafka import KafkaConsumer, KafkaProducer
import numpy as np
import pandas as pd
from io import BytesIO
import time
from collections import deque

# --- Config ---
KAFKA_BOOTSTRAP_SERVERS = os.getenv("KAFKA_BOOTSTRAP_SERVERS", "kafka.apache-kafka.svc.cluster.local:9092")
KAFKA_TOPIC = os.getenv("KAFKA_TOPIC", "sliding_window_lstm")
INFERENCE_URL = os.getenv(
    "INFERENCE_URL",
    "http://inference-serving-kserve-cpu-pct.lstm-iqu.svc.cluster.local/v2/models/inference-serving-kserve-cpu-pct/infer"
)
MINIO_ENDPOINT = os.getenv("MINIO_ENDPOINT", "minio-service.kubeflow.svc.cluster.local:9000")
MINIO_ACCESS_KEY = os.getenv("MINIO_ACCESS_KEY", "minio")
MINIO_SECRET_KEY = os.getenv("MINIO_SECRET_KEY", "minio123")
MINIO_SECURE = os.getenv("MINIO_SECURE", "False").lower() == "true"
MINIO_BUCKET = os.getenv("MINIO_BUCKET", "k8s-resources-forecast")
MINIO_SCALER_OBJECT = os.getenv(
    "MINIO_SCALER_OBJECT",
    "data/k8s-preprocessed/node-1-cpu-scaler/node-1-scaler.pkl"
)
SCALER_FEATURE_NAME = os.getenv("SCALER_FEATURE_NAME", "ac3-node-1-vm_cpu_pct")
FORECAST_TOPIC = os.getenv("FORECAST_TOPIC", "lstm_forecast_values")
METRICS_TOPIC = os.getenv("METRICS_TOPIC", "lstm_forecast_metrics")
FORECAST_HORIZON_SEC = 5   # <--- Adjust this if your horizon is NOT 5 seconds

def fetch_scaler_from_minio():
    client = Minio(
        MINIO_ENDPOINT,
        access_key=MINIO_ACCESS_KEY,
        secret_key=MINIO_SECRET_KEY,
        secure=MINIO_SECURE,
    )
    print(f"Downloading scaler from bucket '{MINIO_BUCKET}' object '{MINIO_SCALER_OBJECT}' ...")
    data = client.get_object(MINIO_BUCKET, MINIO_SCALER_OBJECT)
    scaler = joblib.load(BytesIO(data.read()))
    data.close()
    print("Scaler loaded from MinIO.")
    return scaler

def scale_window(window, scaler, feature_name):
    cpu_vals = np.array([d["cpu_pct"] for d in window]).reshape(-1, 1)
    cpu_df = pd.DataFrame(cpu_vals, columns=[feature_name])
    scaled_vals = scaler.transform(cpu_df)
    return scaled_vals.flatten().tolist()

def send_inference(window_scaled):
    payload = {
        "inputs": [{
            "name": "input-0",
            "shape": [1, len(window_scaled), 1],
            "datatype": "FP32",
            "data": [[ [float(x)] for x in window_scaled ]]
        }]
    }
    try:
        resp = requests.post(INFERENCE_URL, json=payload, timeout=10)
        if resp.status_code == 200:
            result = resp.json()
            return result["outputs"][0]["data"][0]
        else:
            print(f"[ERROR] Inference server HTTP {resp.status_code}: {resp.text}")
            return None
    except Exception as ex:
        print(f"[ERROR] Exception in requests: {ex}")
        return None

def publish_forecast_and_metric(producer, pred_for, pred_made_at, forecasted_value, real_value, error, latency):
    msg_forecast = {
        "prediction_for": pred_for,
        "prediction_made_at": pred_made_at,
        "forecasted_value": forecasted_value,
        "real_value": real_value
    }
    try:
        print("[DEBUG] Publishing forecast to topic:", FORECAST_TOPIC)
        print(msg_forecast)
        producer.send(FORECAST_TOPIC, msg_forecast)
        producer.flush()
    except Exception as e:
        print("[ERROR] Failed to publish forecast:", e)

    if error is not None and latency is not None:
        msg_metrics = {
            "prediction_for": pred_for,
            "error": error,
            "latency_ms": latency
        }
        try:
            print("[DEBUG] Publishing metrics to topic:", METRICS_TOPIC)
            print(msg_metrics)
            producer.send(METRICS_TOPIC, msg_metrics)
            producer.flush()
        except Exception as e:
            print("[ERROR] Failed to publish metrics:", e)

def main():
    scaler = fetch_scaler_from_minio()
    consumer = KafkaConsumer(
        KAFKA_TOPIC,
        bootstrap_servers=[s.strip() for s in KAFKA_BOOTSTRAP_SERVERS.split(",") if s.strip()],
        group_id=None,
        value_deserializer=lambda v: json.loads(v.decode("utf-8")),
        auto_offset_reset="latest",
        enable_auto_commit=False
    )
    producer = KafkaProducer(
        bootstrap_servers=[s.strip() for s in KAFKA_BOOTSTRAP_SERVERS.split(",") if s.strip()],
        value_serializer=lambda v: json.dumps(v).encode("utf-8")
    )

    print(f"Subscribed to topic '{KAFKA_TOPIC}'. Waiting for windows...")

    prediction_queue = deque()

    for msg in consumer:
        window = msg.value
        print("\nReceived window:", " | ".join(f"{d['ts'].split()[-1]} {d['cpu_pct']:.2f}" for d in window))
        window_scaled = scale_window(window, scaler, SCALER_FEATURE_NAME)
        print("\nScaled window:", " | ".join(f"{x:.4f}" for x in window_scaled))
        inference_start = time.time()
        pred = send_inference(window_scaled)
        latency_ms = int((time.time() - inference_start) * 1000)
        # Compute the "prediction_for" timestamp by adding the horizon to last ts
        ts_last = pd.Timestamp(window[-1]['ts'])
        ts_pred_for = (ts_last + pd.Timedelta(seconds=FORECAST_HORIZON_SEC)).strftime("%Y-%m-%d %H:%M:%S")
        ts_pred_made_at = window[-1]['ts']

        if pred is not None:
            pred_rescaled = scaler.inverse_transform(
                pd.DataFrame([[pred]], columns=[SCALER_FEATURE_NAME])
            )[0, 0]
            prediction_queue.append({
                'prediction_for': ts_pred_for,
                'prediction_made_at': ts_pred_made_at,
                'forecasted_value': pred_rescaled,
                'latency': latency_ms
            })
            print(
                f"Prediction for timestamp {ts_pred_for}: {pred_rescaled:.2f} [cpu %] (latency: {latency_ms} ms)"
            )

        # Now check if we have a previous prediction to score (i.e., there are at least 2 items in queue)
        if len(prediction_queue) > 1:
            pending = prediction_queue.popleft()
            # Ground truth for the previous prediction is the *first* value of this window
            gt_ts = window[-1]["ts"]  # Actually, if your windows slide by one, GT is in the first element of current window
            for d in window:
                if d['ts'] == pending['prediction_for']:
                    gt_val = d['cpu_pct']
                    break
            else:
                # If not found, use last as fallback (shouldn't happen unless windows jump)
                gt_val = window[0]['cpu_pct']
            error = abs(pending['forecasted_value'] - gt_val)
            print(
                f"[DEBUG] Previous prediction was for {pending['prediction_for']} (made at {pending['prediction_made_at']}). "
                f"GT: {gt_val:.2f}, Error: {error:.4f}"
            )
            publish_forecast_and_metric(
                producer,
                pred_for=pending['prediction_for'],
                pred_made_at=pending['prediction_made_at'],
                forecasted_value=pending['forecasted_value'],
                real_value=gt_val,
                error=error,
                latency=pending['latency']
            )
        print("-----------------------------------------------------------------------------------------------\n")

if __name__ == "__main__":
    main()
# Out:
# Downloading scaler from bucket 'k8s-resources-forecast' object 'data/k8s-preprocessed/node-1-cpu-scaler/node-1-scaler.pkl' ...
# Scaler loaded from MinIO.
# Subscribed to topic 'sliding_window_lstm'. Waiting for windows...
#
# Received window: 18:29:35 14.60 | 18:29:40 14.60 | 18:29:45 14.60 | 18:29:50 14.92 | 18:29:55 14.92
#
# Scaled window: 0.1478 | 0.1478 | 0.1478 | 0.1513 | 0.1513
# Prediction for timestamp 2025-09-24 18:30:00: 14.49 [cpu %] (latency: 159 ms)
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:29:40 14.60 | 18:29:45 14.60 | 18:29:50 14.92 | 18:29:55 14.92 | 18:30:00 14.92
#
# Scaled window: 0.1478 | 0.1478 | 0.1513 | 0.1513 | 0.1513
# Prediction for timestamp 2025-09-24 18:30:05: 14.56 [cpu %] (latency: 9 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:00 (made at 2025-09-24 18:29:55). GT: 14.92, Error: 0.4328
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:00', 'prediction_made_at': '2025-09-24 18:29:55', 'forecasted_value': 14.489100813865662, 'real_value': 14.92187499999621}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:00', 'error': 0.43277418613054763, 'latency_ms': 159}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:29:45 14.60 | 18:29:50 14.92 | 18:29:55 14.92 | 18:30:00 14.92 | 18:30:05 14.92
#
# Scaled window: 0.1478 | 0.1513 | 0.1513 | 0.1513 | 0.1513
# Prediction for timestamp 2025-09-24 18:30:10: 14.63 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:05 (made at 2025-09-24 18:30:00). GT: 14.92, Error: 0.3574
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:05', 'prediction_made_at': '2025-09-24 18:30:00', 'forecasted_value': 14.56450754404068, 'real_value': 14.92187499999621}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:05', 'error': 0.3573674559555293, 'latency_ms': 9}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:29:50 14.92 | 18:29:55 14.92 | 18:30:00 14.92 | 18:30:05 14.92 | 18:30:10 14.92
#
# Scaled window: 0.1513 | 0.1513 | 0.1513 | 0.1513 | 0.1513
# Prediction for timestamp 2025-09-24 18:30:15: 14.67 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:10 (made at 2025-09-24 18:30:05). GT: 14.92, Error: 0.2938
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:10', 'prediction_made_at': '2025-09-24 18:30:05', 'forecasted_value': 14.62808609008789, 'real_value': 14.92187499999621}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:10', 'error': 0.29378890990831863, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:29:55 14.92 | 18:30:00 14.92 | 18:30:05 14.92 | 18:30:10 14.92 | 18:30:15 14.92
#
# Scaled window: 0.1513 | 0.1513 | 0.1513 | 0.1513 | 0.1513
# Prediction for timestamp 2025-09-24 18:30:20: 14.67 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:15 (made at 2025-09-24 18:30:10). GT: 14.92, Error: 0.2475
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:15', 'prediction_made_at': '2025-09-24 18:30:10', 'forecasted_value': 14.674395322799683, 'real_value': 14.92187499999621}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:15', 'error': 0.24747967719652664, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:00 14.92 | 18:30:05 14.92 | 18:30:10 14.92 | 18:30:15 14.92 | 18:30:20 14.58
#
# Scaled window: 0.1513 | 0.1513 | 0.1513 | 0.1513 | 0.1477
# Prediction for timestamp 2025-09-24 18:30:25: 14.63 [cpu %] (latency: 12 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:20 (made at 2025-09-24 18:30:15). GT: 14.58, Error: 0.0905
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:20', 'prediction_made_at': '2025-09-24 18:30:15', 'forecasted_value': 14.674395322799683, 'real_value': 14.583854166667154}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:20', 'error': 0.09054115613252911, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:05 14.92 | 18:30:10 14.92 | 18:30:15 14.92 | 18:30:20 14.58 | 18:30:25 14.58
#
# Scaled window: 0.1513 | 0.1513 | 0.1513 | 0.1477 | 0.1477
# Prediction for timestamp 2025-09-24 18:30:30: 14.55 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:25 (made at 2025-09-24 18:30:20). GT: 14.58, Error: 0.0418
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:25', 'prediction_made_at': '2025-09-24 18:30:20', 'forecasted_value': 14.62570071220398, 'real_value': 14.583854166667154}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:25', 'error': 0.041846545536825985, 'latency_ms': 12}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:10 14.92 | 18:30:15 14.92 | 18:30:20 14.58 | 18:30:25 14.58 | 18:30:30 14.58
#
# Scaled window: 0.1513 | 0.1513 | 0.1477 | 0.1477 | 0.1477
# Prediction for timestamp 2025-09-24 18:30:35: 14.47 [cpu %] (latency: 34 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:30 (made at 2025-09-24 18:30:25). GT: 14.58, Error: 0.0345
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:30', 'prediction_made_at': '2025-09-24 18:30:25', 'forecasted_value': 14.54940152168274, 'real_value': 14.583854166667154}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:30', 'error': 0.03445264498441425, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:15 14.92 | 18:30:20 14.58 | 18:30:25 14.58 | 18:30:30 14.58 | 18:30:35 14.58
#
# Scaled window: 0.1513 | 0.1477 | 0.1477 | 0.1477 | 0.1477
# Prediction for timestamp 2025-09-24 18:30:40: 14.40 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:35 (made at 2025-09-24 18:30:30). GT: 14.58, Error: 0.1134
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:35', 'prediction_made_at': '2025-09-24 18:30:30', 'forecasted_value': 14.47045373916626, 'real_value': 14.583854166667154}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:35', 'error': 0.11340042750089374, 'latency_ms': 34}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:20 14.58 | 18:30:25 14.58 | 18:30:30 14.58 | 18:30:35 14.58 | 18:30:40 14.58
#
# Scaled window: 0.1477 | 0.1477 | 0.1477 | 0.1477 | 0.1477
# Prediction for timestamp 2025-09-24 18:30:45: 14.36 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:40 (made at 2025-09-24 18:30:35). GT: 14.58, Error: 0.1799
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:40', 'prediction_made_at': '2025-09-24 18:30:35', 'forecasted_value': 14.403937339782715, 'real_value': 14.583854166667154}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:40', 'error': 0.17991682688443866, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:25 14.58 | 18:30:30 14.58 | 18:30:35 14.58 | 18:30:40 14.58 | 18:30:45 14.58
#
# Scaled window: 0.1477 | 0.1477 | 0.1477 | 0.1477 | 0.1477
# Prediction for timestamp 2025-09-24 18:30:50: 14.36 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:45 (made at 2025-09-24 18:30:40). GT: 14.58, Error: 0.2283
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:45', 'prediction_made_at': '2025-09-24 18:30:40', 'forecasted_value': 14.355549812316895, 'real_value': 14.583854166667154}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:45', 'error': 0.22830435435025898, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:30 14.58 | 18:30:35 14.58 | 18:30:40 14.58 | 18:30:45 14.58 | 18:30:50 14.96
#
# Scaled window: 0.1477 | 0.1477 | 0.1477 | 0.1477 | 0.1518
# Prediction for timestamp 2025-09-24 18:30:55: 14.41 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:50 (made at 2025-09-24 18:30:45). GT: 14.96, Error: 0.6064
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:50', 'prediction_made_at': '2025-09-24 18:30:45', 'forecasted_value': 14.355549812316895, 'real_value': 14.96197916667067}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:50', 'error': 0.6064293543537751, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:35 14.58 | 18:30:40 14.58 | 18:30:45 14.58 | 18:30:50 14.96 | 18:30:55 14.96
#
# Scaled window: 0.1477 | 0.1477 | 0.1477 | 0.1518 | 0.1518
# [ERROR] Inference server HTTP 502: readfrom tcp 127.0.0.1:45024->127.0.0.1:8080: write tcp 127.0.0.1:45024->127.0.0.1:8080: use of closed network connection
#
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:40 14.58 | 18:30:45 14.58 | 18:30:50 14.96 | 18:30:55 14.96 | 18:31:00 14.96
#
# Scaled window: 0.1477 | 0.1477 | 0.1518 | 0.1518 | 0.1518
# Prediction for timestamp 2025-09-24 18:31:05: 14.58 [cpu %] (latency: 416 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:30:55 (made at 2025-09-24 18:30:50). GT: 14.96, Error: 0.5520
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:30:55', 'prediction_made_at': '2025-09-24 18:30:50', 'forecasted_value': 14.409956991672516, 'real_value': 14.96197916667067}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:30:55', 'error': 0.5520221749981538, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:45 14.58 | 18:30:50 14.96 | 18:30:55 14.96 | 18:31:00 14.96 | 18:31:05 14.96
#
# Scaled window: 0.1477 | 0.1518 | 0.1518 | 0.1518 | 0.1518
# Prediction for timestamp 2025-09-24 18:31:10: 14.66 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:05 (made at 2025-09-24 18:31:00). GT: 14.96, Error: 0.3784
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:05', 'prediction_made_at': '2025-09-24 18:31:00', 'forecasted_value': 14.583564519882202, 'real_value': 14.96197916667067}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:05', 'error': 0.3784146467884675, 'latency_ms': 416}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:50 14.96 | 18:30:55 14.96 | 18:31:00 14.96 | 18:31:05 14.96 | 18:31:10 14.96
#
# Scaled window: 0.1518 | 0.1518 | 0.1518 | 0.1518 | 0.1518
# Prediction for timestamp 2025-09-24 18:31:15: 14.71 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:10 (made at 2025-09-24 18:31:05). GT: 14.96, Error: 0.3040
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:10', 'prediction_made_at': '2025-09-24 18:31:05', 'forecasted_value': 14.658019840717316, 'real_value': 14.96197916667067}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:10', 'error': 0.30395932595335395, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:30:55 14.96 | 18:31:00 14.96 | 18:31:05 14.96 | 18:31:10 14.96 | 18:31:15 14.96
#
# Scaled window: 0.1518 | 0.1518 | 0.1518 | 0.1518 | 0.1518
# Prediction for timestamp 2025-09-24 18:31:20: 14.71 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:15 (made at 2025-09-24 18:31:10). GT: 14.96, Error: 0.2497
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:15', 'prediction_made_at': '2025-09-24 18:31:10', 'forecasted_value': 14.712259769439697, 'real_value': 14.96197916667067}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:15', 'error': 0.24971939723097236, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:00 14.96 | 18:31:05 14.96 | 18:31:10 14.96 | 18:31:15 14.96 | 18:31:20 14.61
#
# Scaled window: 0.1518 | 0.1518 | 0.1518 | 0.1518 | 0.1479
# Prediction for timestamp 2025-09-24 18:31:25: 14.66 [cpu %] (latency: 101 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:20 (made at 2025-09-24 18:31:15). GT: 14.61, Error: 0.1044
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:20', 'prediction_made_at': '2025-09-24 18:31:15', 'forecasted_value': 14.712259769439697, 'real_value': 14.607812500000817}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:20', 'error': 0.1044472694388805, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:05 14.96 | 18:31:10 14.96 | 18:31:15 14.96 | 18:31:20 14.61 | 18:31:25 14.61
#
# Scaled window: 0.1518 | 0.1518 | 0.1518 | 0.1479 | 0.1479
# Prediction for timestamp 2025-09-24 18:31:30: 14.58 [cpu %] (latency: 105 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:25 (made at 2025-09-24 18:31:20). GT: 14.61, Error: 0.0534
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:25', 'prediction_made_at': '2025-09-24 18:31:20', 'forecasted_value': 14.661229133605957, 'real_value': 14.607812500000817}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:25', 'error': 0.05341663360514026, 'latency_ms': 101}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:10 14.96 | 18:31:15 14.96 | 18:31:20 14.61 | 18:31:25 14.61 | 18:31:30 14.61
#
# Scaled window: 0.1518 | 0.1518 | 0.1479 | 0.1479 | 0.1479
# Prediction for timestamp 2025-09-24 18:31:35: 14.50 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:30 (made at 2025-09-24 18:31:25). GT: 14.61, Error: 0.0265
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:30', 'prediction_made_at': '2025-09-24 18:31:25', 'forecasted_value': 14.58127510547638, 'real_value': 14.607812500000817}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:30', 'error': 0.026537394524437374, 'latency_ms': 105}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:15 14.96 | 18:31:20 14.61 | 18:31:25 14.61 | 18:31:30 14.61 | 18:31:35 14.61
#
# Scaled window: 0.1518 | 0.1479 | 0.1479 | 0.1479 | 0.1479
# Prediction for timestamp 2025-09-24 18:31:40: 14.43 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:35 (made at 2025-09-24 18:31:30). GT: 14.61, Error: 0.1093
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:35', 'prediction_made_at': '2025-09-24 18:31:30', 'forecasted_value': 14.498546361923218, 'real_value': 14.607812500000817}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:35', 'error': 0.109266138077599, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:20 14.61 | 18:31:25 14.61 | 18:31:30 14.61 | 18:31:35 14.61 | 18:31:40 14.61
#
# Scaled window: 0.1479 | 0.1479 | 0.1479 | 0.1479 | 0.1479
# Prediction for timestamp 2025-09-24 18:31:45: 14.38 [cpu %] (latency: 88 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:40 (made at 2025-09-24 18:31:35). GT: 14.61, Error: 0.1790
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:40', 'prediction_made_at': '2025-09-24 18:31:35', 'forecasted_value': 14.42883849143982, 'real_value': 14.607812500000817}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:40', 'error': 0.17897400856099743, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:25 14.61 | 18:31:30 14.61 | 18:31:35 14.61 | 18:31:40 14.61 | 18:31:45 14.61
#
# Scaled window: 0.1479 | 0.1479 | 0.1479 | 0.1479 | 0.1479
# Prediction for timestamp 2025-09-24 18:31:50: 14.38 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:45 (made at 2025-09-24 18:31:40). GT: 14.61, Error: 0.2297
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:45', 'prediction_made_at': '2025-09-24 18:31:40', 'forecasted_value': 14.37813138961792, 'real_value': 14.607812500000817}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:45', 'error': 0.22968111038289685, 'latency_ms': 88}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:30 14.61 | 18:31:35 14.61 | 18:31:40 14.61 | 18:31:45 14.61 | 18:31:50 14.84
#
# Scaled window: 0.1479 | 0.1479 | 0.1479 | 0.1479 | 0.1505
# Prediction for timestamp 2025-09-24 18:31:55: 14.41 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:50 (made at 2025-09-24 18:31:45). GT: 14.84, Error: 0.4646
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:50', 'prediction_made_at': '2025-09-24 18:31:45', 'forecasted_value': 14.37813138961792, 'real_value': 14.842708333327813}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:50', 'error': 0.46457694370989344, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:35 14.61 | 18:31:40 14.61 | 18:31:45 14.61 | 18:31:50 14.84 | 18:31:55 14.84
#
# Scaled window: 0.1479 | 0.1479 | 0.1479 | 0.1505 | 0.1505
# Prediction for timestamp 2025-09-24 18:32:00: 14.46 [cpu %] (latency: 87 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:31:55 (made at 2025-09-24 18:31:50). GT: 14.84, Error: 0.4308
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:31:55', 'prediction_made_at': '2025-09-24 18:31:50', 'forecasted_value': 14.411932468414307, 'real_value': 14.842708333327813}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:31:55', 'error': 0.4307758649135067, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:40 14.61 | 18:31:45 14.61 | 18:31:50 14.84 | 18:31:55 14.84 | 18:32:00 14.84
#
# Scaled window: 0.1479 | 0.1479 | 0.1505 | 0.1505 | 0.1505
# Prediction for timestamp 2025-09-24 18:32:05: 14.52 [cpu %] (latency: 76 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:00 (made at 2025-09-24 18:31:55). GT: 14.84, Error: 0.3778
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:00', 'prediction_made_at': '2025-09-24 18:31:55', 'forecasted_value': 14.46492075920105, 'real_value': 14.842708333327813}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:00', 'error': 0.37778757412676356, 'latency_ms': 87}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:45 14.61 | 18:31:50 14.84 | 18:31:55 14.84 | 18:32:00 14.84 | 18:32:05 14.84
#
# Scaled window: 0.1479 | 0.1505 | 0.1505 | 0.1505 | 0.1505
# Prediction for timestamp 2025-09-24 18:32:10: 14.57 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:05 (made at 2025-09-24 18:32:00). GT: 14.84, Error: 0.3229
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:05', 'prediction_made_at': '2025-09-24 18:32:00', 'forecasted_value': 14.519765257835388, 'real_value': 14.842708333327813}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:05', 'error': 0.3229430754924252, 'latency_ms': 76}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:50 14.84 | 18:31:55 14.84 | 18:32:00 14.84 | 18:32:05 14.84 | 18:32:10 14.84
#
# Scaled window: 0.1505 | 0.1505 | 0.1505 | 0.1505 | 0.1505
# Prediction for timestamp 2025-09-24 18:32:15: 14.60 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:10 (made at 2025-09-24 18:32:05). GT: 14.84, Error: 0.2767
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:10', 'prediction_made_at': '2025-09-24 18:32:05', 'forecasted_value': 14.566003203392029, 'real_value': 14.842708333327813}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:10', 'error': 0.27670512993578456, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:31:55 14.84 | 18:32:00 14.84 | 18:32:05 14.84 | 18:32:10 14.84 | 18:32:15 14.84
#
# Scaled window: 0.1505 | 0.1505 | 0.1505 | 0.1505 | 0.1505
# Prediction for timestamp 2025-09-24 18:32:20: 14.60 [cpu %] (latency: 474 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:15 (made at 2025-09-24 18:32:10). GT: 14.84, Error: 0.2430
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:15', 'prediction_made_at': '2025-09-24 18:32:10', 'forecasted_value': 14.599672675132751, 'real_value': 14.842708333327813}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:15', 'error': 0.2430356581950619, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:00 14.84 | 18:32:05 14.84 | 18:32:10 14.84 | 18:32:15 14.84 | 18:32:20 14.74
#
# Scaled window: 0.1505 | 0.1505 | 0.1505 | 0.1505 | 0.1493
# Prediction for timestamp 2025-09-24 18:32:25: 14.58 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:20 (made at 2025-09-24 18:32:15). GT: 14.74, Error: 0.1389
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:20', 'prediction_made_at': '2025-09-24 18:32:15', 'forecasted_value': 14.599672675132751, 'real_value': 14.738541666675554}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:20', 'error': 0.13886899154280208, 'latency_ms': 474}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:05 14.84 | 18:32:10 14.84 | 18:32:15 14.84 | 18:32:20 14.74 | 18:32:25 14.74
#
# Scaled window: 0.1505 | 0.1505 | 0.1505 | 0.1493 | 0.1493
# Prediction for timestamp 2025-09-24 18:32:30: 14.56 [cpu %] (latency: 68 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:25 (made at 2025-09-24 18:32:20). GT: 14.74, Error: 0.1539
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:25', 'prediction_made_at': '2025-09-24 18:32:20', 'forecasted_value': 14.584668099880219, 'real_value': 14.738541666675554}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:25', 'error': 0.15387356679533504, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:10 14.84 | 18:32:15 14.84 | 18:32:20 14.74 | 18:32:25 14.74 | 18:32:30 14.74
#
# Scaled window: 0.1505 | 0.1505 | 0.1493 | 0.1493 | 0.1493
# Prediction for timestamp 2025-09-24 18:32:35: 14.54 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:30 (made at 2025-09-24 18:32:25). GT: 14.74, Error: 0.1774
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:30', 'prediction_made_at': '2025-09-24 18:32:25', 'forecasted_value': 14.561158418655396, 'real_value': 14.738541666675554}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:30', 'error': 0.17738324802015804, 'latency_ms': 68}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:15 14.84 | 18:32:20 14.74 | 18:32:25 14.74 | 18:32:30 14.74 | 18:32:35 14.74
#
# Scaled window: 0.1505 | 0.1493 | 0.1493 | 0.1493 | 0.1493
# Prediction for timestamp 2025-09-24 18:32:40: 14.52 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:35 (made at 2025-09-24 18:32:30). GT: 14.74, Error: 0.2017
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:35', 'prediction_made_at': '2025-09-24 18:32:30', 'forecasted_value': 14.536826193332672, 'real_value': 14.738541666675554}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:35', 'error': 0.20171547334288142, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:20 14.74 | 18:32:25 14.74 | 18:32:30 14.74 | 18:32:35 14.74 | 18:32:40 14.74
#
# Scaled window: 0.1493 | 0.1493 | 0.1493 | 0.1493 | 0.1493
# Prediction for timestamp 2025-09-24 18:32:45: 14.50 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:40 (made at 2025-09-24 18:32:35). GT: 14.74, Error: 0.2222
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:40', 'prediction_made_at': '2025-09-24 18:32:35', 'forecasted_value': 14.516321539878845, 'real_value': 14.738541666675554}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:40', 'error': 0.22222012679670833, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:25 14.74 | 18:32:30 14.74 | 18:32:35 14.74 | 18:32:40 14.74 | 18:32:45 14.74
#
# Scaled window: 0.1493 | 0.1493 | 0.1493 | 0.1493 | 0.1493
# Prediction for timestamp 2025-09-24 18:32:50: 14.50 [cpu %] (latency: 13 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:45 (made at 2025-09-24 18:32:40). GT: 14.74, Error: 0.2371
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:45', 'prediction_made_at': '2025-09-24 18:32:40', 'forecasted_value': 14.501396477222443, 'real_value': 14.738541666675554}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:45', 'error': 0.23714518945311092, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:30 14.74 | 18:32:35 14.74 | 18:32:40 14.74 | 18:32:45 14.74 | 18:32:50 15.99
#
# Scaled window: 0.1493 | 0.1493 | 0.1493 | 0.1493 | 0.1629
# Prediction for timestamp 2025-09-24 18:32:55: 14.68 [cpu %] (latency: 645 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:50 (made at 2025-09-24 18:32:45). GT: 15.99, Error: 1.4887
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:50', 'prediction_made_at': '2025-09-24 18:32:45', 'forecasted_value': 14.501396477222443, 'real_value': 15.990104166657282}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:50', 'error': 1.4887076894348397, 'latency_ms': 13}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:35 14.74 | 18:32:40 14.74 | 18:32:45 14.74 | 18:32:50 15.99 | 18:32:55 15.99
#
# Scaled window: 0.1493 | 0.1493 | 0.1493 | 0.1629 | 0.1629
# Prediction for timestamp 2025-09-24 18:33:00: 14.96 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:32:55 (made at 2025-09-24 18:32:50). GT: 15.99, Error: 1.3084
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:32:55', 'prediction_made_at': '2025-09-24 18:32:50', 'forecasted_value': 14.681711852550507, 'real_value': 15.990104166657304}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:32:55', 'error': 1.308392314106797, 'latency_ms': 645}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:40 14.74 | 18:32:45 14.74 | 18:32:50 15.99 | 18:32:55 15.99 | 18:33:00 15.99
#
# Scaled window: 0.1493 | 0.1493 | 0.1629 | 0.1629 | 0.1629
# Prediction for timestamp 2025-09-24 18:33:05: 15.26 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:00 (made at 2025-09-24 18:32:55). GT: 15.99, Error: 1.0256
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:00', 'prediction_made_at': '2025-09-24 18:32:55', 'forecasted_value': 14.964497029781342, 'real_value': 15.990104166657304}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:00', 'error': 1.025607136875962, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:45 14.74 | 18:32:50 15.99 | 18:32:55 15.99 | 18:33:00 15.99 | 18:33:05 15.99
#
# Scaled window: 0.1493 | 0.1629 | 0.1629 | 0.1629 | 0.1629
# Prediction for timestamp 2025-09-24 18:33:10: 15.50 [cpu %] (latency: 108 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:05 (made at 2025-09-24 18:33:00). GT: 15.99, Error: 0.7327
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:05', 'prediction_made_at': '2025-09-24 18:33:00', 'forecasted_value': 15.25741457939148, 'real_value': 15.990104166657304}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:05', 'error': 0.7326895872658241, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:50 15.99 | 18:32:55 15.99 | 18:33:00 15.99 | 18:33:05 15.99 | 18:33:10 15.99
#
# Scaled window: 0.1629 | 0.1629 | 0.1629 | 0.1629 | 0.1629
# Prediction for timestamp 2025-09-24 18:33:15: 15.69 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:10 (made at 2025-09-24 18:33:05). GT: 15.99, Error: 0.4853
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:10', 'prediction_made_at': '2025-09-24 18:33:05', 'forecasted_value': 15.504791975021362, 'real_value': 15.990104166657304}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:10', 'error': 0.4853121916359413, 'latency_ms': 108}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:32:55 15.99 | 18:33:00 15.99 | 18:33:05 15.99 | 18:33:10 15.99 | 18:33:15 15.99
#
# Scaled window: 0.1629 | 0.1629 | 0.1629 | 0.1629 | 0.1629
# Prediction for timestamp 2025-09-24 18:33:20: 15.69 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:15 (made at 2025-09-24 18:33:10). GT: 15.99, Error: 0.3046
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:15', 'prediction_made_at': '2025-09-24 18:33:10', 'forecasted_value': 15.685514509677887, 'real_value': 15.990104166657304}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:15', 'error': 0.30458965697941665, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:00 15.99 | 18:33:05 15.99 | 18:33:10 15.99 | 18:33:15 15.99 | 18:33:20 15.77
#
# Scaled window: 0.1629 | 0.1629 | 0.1629 | 0.1629 | 0.1606
# Prediction for timestamp 2025-09-24 18:33:25: 15.65 [cpu %] (latency: 12 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:20 (made at 2025-09-24 18:33:15). GT: 15.77, Error: 0.0890
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:20', 'prediction_made_at': '2025-09-24 18:33:15', 'forecasted_value': 15.685514509677887, 'real_value': 15.774479166673249}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:20', 'error': 0.08896465699536193, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:05 15.99 | 18:33:10 15.99 | 18:33:15 15.99 | 18:33:20 15.77 | 18:33:25 15.77
#
# Scaled window: 0.1629 | 0.1629 | 0.1629 | 0.1606 | 0.1606
# Prediction for timestamp 2025-09-24 18:33:30: 15.61 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:25 (made at 2025-09-24 18:33:20). GT: 15.77, Error: 0.1202
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:25', 'prediction_made_at': '2025-09-24 18:33:20', 'forecasted_value': 15.654292106628418, 'real_value': 15.774479166673249}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:25', 'error': 0.12018706004483093, 'latency_ms': 12}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:10 15.99 | 18:33:15 15.99 | 18:33:20 15.77 | 18:33:25 15.77 | 18:33:30 15.77
#
# Scaled window: 0.1629 | 0.1629 | 0.1606 | 0.1606 | 0.1606
# Prediction for timestamp 2025-09-24 18:33:35: 15.55 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:30 (made at 2025-09-24 18:33:25). GT: 15.77, Error: 0.1691
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:30', 'prediction_made_at': '2025-09-24 18:33:25', 'forecasted_value': 15.605413794517517, 'real_value': 15.774479166673249}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:30', 'error': 0.1690653721557318, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:15 15.99 | 18:33:20 15.77 | 18:33:25 15.77 | 18:33:30 15.77 | 18:33:35 15.77
#
# Scaled window: 0.1629 | 0.1606 | 0.1606 | 0.1606 | 0.1606
# Prediction for timestamp 2025-09-24 18:33:40: 15.51 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:35 (made at 2025-09-24 18:33:30). GT: 15.77, Error: 0.2197
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:35', 'prediction_made_at': '2025-09-24 18:33:30', 'forecasted_value': 15.554816365242004, 'real_value': 15.774479166673249}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:35', 'error': 0.2196628014312445, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:20 15.77 | 18:33:25 15.77 | 18:33:30 15.77 | 18:33:35 15.77 | 18:33:40 15.77
#
# Scaled window: 0.1606 | 0.1606 | 0.1606 | 0.1606 | 0.1606
# Prediction for timestamp 2025-09-24 18:33:45: 15.48 [cpu %] (latency: 19 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:40 (made at 2025-09-24 18:33:35). GT: 15.77, Error: 0.2624
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:40', 'prediction_made_at': '2025-09-24 18:33:35', 'forecasted_value': 15.512123584747314, 'real_value': 15.774479166673249}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:40', 'error': 0.26235558192593444, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:25 15.77 | 18:33:30 15.77 | 18:33:35 15.77 | 18:33:40 15.77 | 18:33:45 15.77
#
# Scaled window: 0.1606 | 0.1606 | 0.1606 | 0.1606 | 0.1606
# Prediction for timestamp 2025-09-24 18:33:50: 15.48 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:45 (made at 2025-09-24 18:33:40). GT: 15.77, Error: 0.2935
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:45', 'prediction_made_at': '2025-09-24 18:33:40', 'forecasted_value': 15.480993032455444, 'real_value': 15.774479166673249}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:45', 'error': 0.29348613421780456, 'latency_ms': 19}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:30 15.77 | 18:33:35 15.77 | 18:33:40 15.77 | 18:33:45 15.77 | 18:33:50 15.84
#
# Scaled window: 0.1606 | 0.1606 | 0.1606 | 0.1606 | 0.1613
# Prediction for timestamp 2025-09-24 18:33:55: 15.49 [cpu %] (latency: 101 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:50 (made at 2025-09-24 18:33:45). GT: 15.84, Error: 0.3555
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:50', 'prediction_made_at': '2025-09-24 18:33:45', 'forecasted_value': 15.480993032455444, 'real_value': 15.836458333327908}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:50', 'error': 0.35546530087246353, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:35 15.77 | 18:33:40 15.77 | 18:33:45 15.77 | 18:33:50 15.84 | 18:33:55 15.84
#
# Scaled window: 0.1606 | 0.1606 | 0.1606 | 0.1613 | 0.1613
# Prediction for timestamp 2025-09-24 18:34:00: 15.50 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:33:55 (made at 2025-09-24 18:33:50). GT: 15.84, Error: 0.3465
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:33:55', 'prediction_made_at': '2025-09-24 18:33:50', 'forecasted_value': 15.489961504936218, 'real_value': 15.836458333327908}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:33:55', 'error': 0.3464968283916896, 'latency_ms': 101}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:40 15.77 | 18:33:45 15.77 | 18:33:50 15.84 | 18:33:55 15.84 | 18:34:00 15.84
#
# Scaled window: 0.1606 | 0.1606 | 0.1613 | 0.1613 | 0.1613
# Prediction for timestamp 2025-09-24 18:34:05: 15.52 [cpu %] (latency: 198 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:00 (made at 2025-09-24 18:33:55). GT: 15.84, Error: 0.3325
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:00', 'prediction_made_at': '2025-09-24 18:33:55', 'forecasted_value': 15.504002332687378, 'real_value': 15.836458333327908}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:00', 'error': 0.33245600064052994, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:45 15.77 | 18:33:50 15.84 | 18:33:55 15.84 | 18:34:00 15.84 | 18:34:05 15.84
#
# Scaled window: 0.1606 | 0.1613 | 0.1613 | 0.1613 | 0.1613
# Prediction for timestamp 2025-09-24 18:34:10: 15.53 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:05 (made at 2025-09-24 18:34:00). GT: 15.84, Error: 0.3179
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:05', 'prediction_made_at': '2025-09-24 18:34:00', 'forecasted_value': 15.518540799617767, 'real_value': 15.836458333327908}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:05', 'error': 0.31791753371014053, 'latency_ms': 198}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:50 15.84 | 18:33:55 15.84 | 18:34:00 15.84 | 18:34:05 15.84 | 18:34:10 15.84
#
# Scaled window: 0.1613 | 0.1613 | 0.1613 | 0.1613 | 0.1613
# Prediction for timestamp 2025-09-24 18:34:15: 15.54 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:10 (made at 2025-09-24 18:34:05). GT: 15.84, Error: 0.3056
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:10', 'prediction_made_at': '2025-09-24 18:34:05', 'forecasted_value': 15.530809044837952, 'real_value': 15.836458333327908}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:10', 'error': 0.3056492884899562, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:33:55 15.84 | 18:34:00 15.84 | 18:34:05 15.84 | 18:34:10 15.84 | 18:34:15 15.84
#
# Scaled window: 0.1613 | 0.1613 | 0.1613 | 0.1613 | 0.1613
# Prediction for timestamp 2025-09-24 18:34:20: 15.54 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:15 (made at 2025-09-24 18:34:10). GT: 15.84, Error: 0.2967
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:15', 'prediction_made_at': '2025-09-24 18:34:10', 'forecasted_value': 15.539761066436768, 'real_value': 15.836458333327908}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:15', 'error': 0.2966972668911403, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:00 15.84 | 18:34:05 15.84 | 18:34:10 15.84 | 18:34:15 15.84 | 18:34:20 15.80
#
# Scaled window: 0.1613 | 0.1613 | 0.1613 | 0.1613 | 0.1609
# Prediction for timestamp 2025-09-24 18:34:25: 15.54 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:20 (made at 2025-09-24 18:34:15). GT: 15.80, Error: 0.2649
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:20', 'prediction_made_at': '2025-09-24 18:34:15', 'forecasted_value': 15.539761066436768, 'real_value': 15.804687500003645}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:20', 'error': 0.2649264335668775, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:05 15.84 | 18:34:10 15.84 | 18:34:15 15.84 | 18:34:20 15.80 | 18:34:25 15.80
#
# Scaled window: 0.1613 | 0.1613 | 0.1613 | 0.1609 | 0.1609
# Prediction for timestamp 2025-09-24 18:34:30: 15.53 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:25 (made at 2025-09-24 18:34:20). GT: 15.80, Error: 0.2695
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:25', 'prediction_made_at': '2025-09-24 18:34:20', 'forecasted_value': 15.535163044929504, 'real_value': 15.804687500003645}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:25', 'error': 0.2695244550741407, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:10 15.84 | 18:34:15 15.84 | 18:34:20 15.80 | 18:34:25 15.80 | 18:34:30 15.80
#
# Scaled window: 0.1613 | 0.1613 | 0.1609 | 0.1609 | 0.1609
# Prediction for timestamp 2025-09-24 18:34:35: 15.52 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:30 (made at 2025-09-24 18:34:25). GT: 15.80, Error: 0.2767
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:30', 'prediction_made_at': '2025-09-24 18:34:25', 'forecasted_value': 15.527963042259216, 'real_value': 15.804687500003645}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:30', 'error': 0.2767244577444288, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:15 15.84 | 18:34:20 15.80 | 18:34:25 15.80 | 18:34:30 15.80 | 18:34:35 15.80
#
# Scaled window: 0.1613 | 0.1609 | 0.1609 | 0.1609 | 0.1609
# Prediction for timestamp 2025-09-24 18:34:40: 15.51 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:35 (made at 2025-09-24 18:34:30). GT: 15.80, Error: 0.2842
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:35', 'prediction_made_at': '2025-09-24 18:34:30', 'forecasted_value': 15.520509421825409, 'real_value': 15.804687500003645}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:35', 'error': 0.28417807817823615, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:20 15.80 | 18:34:25 15.80 | 18:34:30 15.80 | 18:34:35 15.80 | 18:34:40 15.80
#
# Scaled window: 0.1609 | 0.1609 | 0.1609 | 0.1609 | 0.1609
# Prediction for timestamp 2025-09-24 18:34:45: 15.51 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:40 (made at 2025-09-24 18:34:35). GT: 15.80, Error: 0.2905
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:40', 'prediction_made_at': '2025-09-24 18:34:35', 'forecasted_value': 15.51421970129013, 'real_value': 15.804687500003645}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:40', 'error': 0.29046779871351447, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:25 15.80 | 18:34:30 15.80 | 18:34:35 15.80 | 18:34:40 15.80 | 18:34:45 15.80
#
# Scaled window: 0.1609 | 0.1609 | 0.1609 | 0.1609 | 0.1609
# Prediction for timestamp 2025-09-24 18:34:50: 15.51 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:45 (made at 2025-09-24 18:34:40). GT: 15.80, Error: 0.2951
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:45', 'prediction_made_at': '2025-09-24 18:34:40', 'forecasted_value': 15.509634017944336, 'real_value': 15.804687500003645}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:45', 'error': 0.29505348205930915, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:30 15.80 | 18:34:35 15.80 | 18:34:40 15.80 | 18:34:45 15.80 | 18:34:50 15.62
#
# Scaled window: 0.1609 | 0.1609 | 0.1609 | 0.1609 | 0.1589
# Prediction for timestamp 2025-09-24 18:34:55: 15.48 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:50 (made at 2025-09-24 18:34:45). GT: 15.62, Error: 0.1122
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:50', 'prediction_made_at': '2025-09-24 18:34:45', 'forecasted_value': 15.509634017944336, 'real_value': 15.621875000003161}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:50', 'error': 0.11224098205882527, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:35 15.80 | 18:34:40 15.80 | 18:34:45 15.80 | 18:34:50 15.62 | 18:34:55 15.62
#
# Scaled window: 0.1609 | 0.1609 | 0.1609 | 0.1589 | 0.1589
# Prediction for timestamp 2025-09-24 18:35:00: 15.44 [cpu %] (latency: 273 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:34:55 (made at 2025-09-24 18:34:50). GT: 15.62, Error: 0.1387
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:34:55', 'prediction_made_at': '2025-09-24 18:34:50', 'forecasted_value': 15.483183741569519, 'real_value': 15.621875000003161}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:34:55', 'error': 0.13869125843364216, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:40 15.80 | 18:34:45 15.80 | 18:34:50 15.62 | 18:34:55 15.62 | 18:35:00 15.62
#
# Scaled window: 0.1609 | 0.1609 | 0.1589 | 0.1589 | 0.1589
# Prediction for timestamp 2025-09-24 18:35:05: 15.40 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:35:00 (made at 2025-09-24 18:34:55). GT: 15.62, Error: 0.1801
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:35:00', 'prediction_made_at': '2025-09-24 18:34:55', 'forecasted_value': 15.441771388053894, 'real_value': 15.621875000003161}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:35:00', 'error': 0.18010361194926716, 'latency_ms': 273}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:45 15.80 | 18:34:50 15.62 | 18:34:55 15.62 | 18:35:00 15.62 | 18:35:05 15.62
#
# Scaled window: 0.1609 | 0.1589 | 0.1589 | 0.1589 | 0.1589
# Prediction for timestamp 2025-09-24 18:35:10: 15.36 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:35:05 (made at 2025-09-24 18:35:00). GT: 15.62, Error: 0.2230
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:35:05', 'prediction_made_at': '2025-09-24 18:35:00', 'forecasted_value': 15.398903131484985, 'real_value': 15.621875000003161}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:35:05', 'error': 0.22297186851817585, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:50 15.62 | 18:34:55 15.62 | 18:35:00 15.62 | 18:35:05 15.62 | 18:35:10 15.62
#
# Scaled window: 0.1589 | 0.1589 | 0.1589 | 0.1589 | 0.1589
# Prediction for timestamp 2025-09-24 18:35:15: 15.34 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:35:10 (made at 2025-09-24 18:35:05). GT: 15.62, Error: 0.2591
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:35:10', 'prediction_made_at': '2025-09-24 18:35:05', 'forecasted_value': 15.362738609313965, 'real_value': 15.621875000003161}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:35:10', 'error': 0.25913639068919636, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:34:55 15.62 | 18:35:00 15.62 | 18:35:05 15.62 | 18:35:10 15.62 | 18:35:15 15.62
#
# Scaled window: 0.1589 | 0.1589 | 0.1589 | 0.1589 | 0.1589
# Prediction for timestamp 2025-09-24 18:35:20: 15.34 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:35:15 (made at 2025-09-24 18:35:10). GT: 15.62, Error: 0.2855
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:35:15', 'prediction_made_at': '2025-09-24 18:35:10', 'forecasted_value': 15.336378812789917, 'real_value': 15.621875000003161}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:35:15', 'error': 0.2854961872132442, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:35:00 15.62 | 18:35:05 15.62 | 18:35:10 15.62 | 18:35:15 15.62 | 18:35:20 15.41
#
# Scaled window: 0.1589 | 0.1589 | 0.1589 | 0.1589 | 0.1567
# Prediction for timestamp 2025-09-24 18:35:25: 15.31 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:35:20 (made at 2025-09-24 18:35:15). GT: 15.41, Error: 0.0766
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:35:20', 'prediction_made_at': '2025-09-24 18:35:15', 'forecasted_value': 15.336378812789917, 'real_value': 15.413020833327662}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:35:20', 'error': 0.07664202053774538, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:35:05 15.62 | 18:35:10 15.62 | 18:35:15 15.62 | 18:35:20 15.41 | 18:35:25 15.41
#
# Scaled window: 0.1589 | 0.1589 | 0.1589 | 0.1567 | 0.1567
# Prediction for timestamp 2025-09-24 18:35:30: 15.26 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:35:25 (made at 2025-09-24 18:35:20). GT: 15.41, Error: 0.1068
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:35:25', 'prediction_made_at': '2025-09-24 18:35:20', 'forecasted_value': 15.306187331676483, 'real_value': 15.41302083332765}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:35:25', 'error': 0.10683350165116678, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:35:10 15.62 | 18:35:15 15.62 | 18:35:20 15.41 | 18:35:25 15.41 | 18:35:30 15.41
#
# Scaled window: 0.1589 | 0.1589 | 0.1567 | 0.1567 | 0.1567
# Prediction for timestamp 2025-09-24 18:35:35: 15.21 [cpu %] (latency: 10 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:35:30 (made at 2025-09-24 18:35:25). GT: 15.41, Error: 0.1541
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:35:30', 'prediction_made_at': '2025-09-24 18:35:25', 'forecasted_value': 15.258910238742828, 'real_value': 15.41302083332765}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:35:30', 'error': 0.15411059458482157, 'latency_ms': 11}
# -----------------------------------------------------------------------------------------------
#
#
# Received window: 18:35:15 15.62 | 18:35:20 15.41 | 18:35:25 15.41 | 18:35:30 15.41 | 18:35:35 15.41
#
# Scaled window: 0.1589 | 0.1567 | 0.1567 | 0.1567 | 0.1567
# Prediction for timestamp 2025-09-24 18:35:40: 15.17 [cpu %] (latency: 11 ms)
# [DEBUG] Previous prediction was for 2025-09-24 18:35:35 (made at 2025-09-24 18:35:30). GT: 15.41, Error: 0.2030
# [DEBUG] Publishing forecast to topic: lstm_forecast_values
# {'prediction_for': '2025-09-24 18:35:35', 'prediction_made_at': '2025-09-24 18:35:30', 'forecasted_value': 15.209974348545074, 'real_value': 15.413020833327662}
# [DEBUG] Publishing metrics to topic: lstm_forecast_metrics
# {'prediction_for': '2025-09-24 18:35:35', 'error': 0.2030464847825879, 'latency_ms': 10}
# -----------------------------------------------------------------------------------------------
