# %%
deployment = deploy_nhits_model(
    registered_model_name="nhits-model",
    model_alias="champion",
    service_name="nhits-model",
    namespace="lstm-iqu",
    mlflow_tracking_uri="http://sunrise-mlflow-tracking.mlflow.svc.cluster.local:5080",
    runtime_name="kserve-mlserver-nhits",
    service_account_name="sa-private-mlflow",
    s3_prefix="s3://mlflow",
)

deployment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from deploy_nhits_kserve_component import deploy_nhits_model
# ----> 3 deployment = deploy_nhits_model(
#       4     registered_model_name="nhits-model",
#       5     model_alias="champion",
#       6     service_name="nhits-model",
#       7     namespace="lstm-iqu",
#       8     mlflow_tracking_uri="http://sunrise-mlflow-tracking.mlflow.svc.cluster.local:5080",
#       9     runtime_name="kserve-mlserver-nhits",
#      10     service_account_name="sa-private-mlflow",
#      11     s3_prefix="s3://mlflow",
#      12 )
#      14 deployment
#
# TypeError: deploy_nhits_model() got an unexpected keyword argument 's3_prefix'
