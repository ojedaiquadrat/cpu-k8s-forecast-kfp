# %%
from deploy_nhits_kserve_component import deploy_nhits_model

deployment = deploy_nhits_model(
    registered_model_name="nhits-model",
    model_alias="champion",
    service_name="nhits-model",
    namespace="lstm-iqu",
    mlflow_tracking_uri="http://sunrise-mlflow-tracking.mlflow.svc.cluster.local:5080",
    runtime_name="kserve-mlserver-nhits",
    service_account_name="sa-private-mlflow",
    s3_prefix="s3://mlflow",
    model_subpath="model_artifacts",
)

deployment
# Out:
# 2026-03-25 10:34:53,097 INFO deploy_nhits_kserve - Loaded in-cluster Kubernetes configuration.
# 2026-03-25 10:34:53,097 INFO deploy_nhits_kserve - Resolving MLflow model alias 'champion' for model 'nhits-model'.
# 2026-03-25 10:34:53,129 INFO deploy_nhits_kserve - Resolved run_id=fbfc00ae272d42bfa61386b90a984c5e storage_uri=s3://mlflow/24/fbfc00ae272d42bfa61386b90a984c5e/artifacts/model_artifacts
# 2026-03-25 10:34:53,161 INFO deploy_nhits_kserve - InferenceService 'nhits-model' does not exist yet in namespace 'lstm-iqu'; creating it.
# 2026-03-25 10:34:53,177 INFO deploy_nhits_kserve - Waiting up to 900 seconds for InferenceService 'nhits-model' to become Ready.
# 2026-03-25 10:39:43,595 INFO deploy_nhits_kserve - Deployment completed successfully: {
#   "model_name": "nhits-model",
#   "model_alias": "champion",
#   "service_name": "nhits-model",
#   "namespace": "lstm-iqu",
#   "runtime": "kserve-mlserver-nhits",
#   "run_id": "fbfc00ae272d42bfa61386b90a984c5e",
# ...
