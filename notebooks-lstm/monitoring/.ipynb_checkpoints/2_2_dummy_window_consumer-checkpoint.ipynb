# %%
import json
from kafka import KafkaConsumer, KafkaProducer
import random

#Topic for getting the data fro inference
INPUT_TOPIC = "dummy-windowed"
#New to integrate
# Topic for the grafana. you can add more as is shown below
OUTPUT_TOPIC = "dummy-aggregated"
BOOTSTRAP_SERVERS = ["kafka.apache-kafka.svc.cluster.local:9092"]

# Consumer your already have it
consumer = KafkaConsumer(
    INPUT_TOPIC,
    bootstrap_servers=BOOTSTRAP_SERVERS,
    value_deserializer=lambda v: json.loads(v.decode("utf-8")),
    auto_offset_reset="latest",
    enable_auto_commit=True,
    group_id="sum-computation-group"
)

# New to integrate: Add Producer
producer = KafkaProducer(
    bootstrap_servers=BOOTSTRAP_SERVERS,
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)

print(f"Listening on topic {INPUT_TOPIC} and publishing to {OUTPUT_TOPIC}")

for msg in consumer:
    data = msg.value

    values = []
    ts = None

    if "inputs" in data:
        for item in data["inputs"]:
            if isinstance(item, list) and len(item) > 0:
                entry = item[0]
                val = entry.get("value")
                if val is not None:
                    values.append(val)
                if ts is None:  # take timestamp from first element
                    ts = entry.get("timestamp")
    #total = forecasted value
    forecasted_value = sum(values)
    real_value= random.randint(0, 5)

    #only to print the output
    result = {
        "timestamp": ts,
        "inference": round(forecasted_value, 6),
        "real-value": real_value
    }
     
    ##New to integrate
    ##Publish the data in a new topic . you can group several metrics yo see in ine grafana to avoid creating more topics
    producer.send(OUTPUT_TOPIC, value=result)
    print("Published:", result)
    
    ##Publish the data in a new topic if oyu wan to add more 
    #producer.send("real_value", value=result)
    #print("Published:", result)
# Out:
# Listening on topic dummy-windowed and publishing to dummy-aggregated
# Published: {'timestamp': '2025-09-23T14:34:42.108275', 'inference': 2.67964, 'real-value': 5}
# Published: {'timestamp': '2025-09-23T14:34:47.108796', 'inference': 2.903258, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:34:52.109310', 'inference': 2.970063, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:34:57.109901', 'inference': 3.629184, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:35:02.110377', 'inference': 2.2745, 'real-value': 3}
# Published: {'timestamp': '2025-09-23T14:35:07.111002', 'inference': 3.832336, 'real-value': 3}
# Published: {'timestamp': '2025-09-23T14:35:12.111852', 'inference': 3.112379, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:35:17.112509', 'inference': 2.874684, 'real-value': 0}
# Published: {'timestamp': '2025-09-23T14:35:22.113075', 'inference': 2.641941, 'real-value': 0}
# Published: {'timestamp': '2025-09-23T14:35:27.113581', 'inference': 3.134342, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:35:32.114191', 'inference': 2.330198, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:35:37.114659', 'inference': 2.353262, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:35:42.115218', 'inference': 3.639694, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:35:47.115662', 'inference': 3.001002, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:35:52.116113', 'inference': 3.262527, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:35:57.116594', 'inference': 3.241648, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:36:02.117079', 'inference': 2.872121, 'real-value': 0}
# Published: {'timestamp': '2025-09-23T14:36:07.117578', 'inference': 3.435104, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:36:12.118094', 'inference': 2.517113, 'real-value': 3}
# Published: {'timestamp': '2025-09-23T14:36:17.118557', 'inference': 2.414299, 'real-value': 5}
# Published: {'timestamp': '2025-09-23T14:36:22.119191', 'inference': 2.585321, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:36:27.119658', 'inference': 3.018831, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:36:32.120132', 'inference': 2.464189, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:36:37.120586', 'inference': 3.620784, 'real-value': 0}
# Published: {'timestamp': '2025-09-23T14:36:42.121062', 'inference': 2.66504, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:36:47.121557', 'inference': 3.470601, 'real-value': 3}
# Published: {'timestamp': '2025-09-23T14:36:52.122025', 'inference': 2.839119, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:36:57.122476', 'inference': 3.207743, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:37:02.122927', 'inference': 2.586246, 'real-value': 3}
# Published: {'timestamp': '2025-09-23T14:37:07.123422', 'inference': 2.871891, 'real-value': 3}
# Published: {'timestamp': '2025-09-23T14:37:12.123892', 'inference': 2.422213, 'real-value': 0}
# Published: {'timestamp': '2025-09-23T14:37:17.124476', 'inference': 2.635084, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:37:22.124970', 'inference': 2.443471, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:37:27.125414', 'inference': 3.712147, 'real-value': 5}
# Published: {'timestamp': '2025-09-23T14:37:32.126123', 'inference': 2.691581, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:37:37.126629', 'inference': 3.706946, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:37:42.127084', 'inference': 3.882095, 'real-value': 5}
# Published: {'timestamp': '2025-09-23T14:37:47.127684', 'inference': 2.392986, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:37:52.128172', 'inference': 2.393302, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:37:57.128633', 'inference': 2.405479, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:38:02.129108', 'inference': 2.733135, 'real-value': 1}
# Published: {'timestamp': '2025-09-23T14:38:07.129659', 'inference': 4.030272, 'real-value': 4}
# Published: {'timestamp': '2025-09-23T14:38:12.130118', 'inference': 2.987249, 'real-value': 2}
# Published: {'timestamp': '2025-09-23T14:38:17.130574', 'inference': 2.045812, 'real-value': 0}
